# %%
import pandas as pd

# %%
data = pd.read_csv('products-2.csv', sep='\t')

# %%
# numeric description of the data
data.describe()
# Out:
#         ProductID    MakeFlag  FinishedGoodsFlag  SafetyStockLevel  \
# count  504.000000  504.000000         504.000000        504.000000
# mean   673.039683    0.474206           0.585317        535.150794
# std    229.373142    0.499830           0.493157        374.112954
# min      1.000000    0.000000           0.000000          4.000000
# 25%    447.750000    0.000000           0.000000        100.000000
# 50%    747.500000    0.000000           1.000000        500.000000
# 75%    873.250000    1.000000           1.000000       1000.000000
# max    999.000000    1.000000           1.000000       1000.000000
#
#        ReorderPoint  StandardCost    ListPrice       Weight  \
# count    504.000000    504.000000   504.000000   205.000000
# mean     401.363095    258.602961   438.666250    74.069220
# std      280.584715    461.632808   773.602843   182.166588
# min        3.000000      0.000000     0.000000     2.120000
# ...

# %%
# shape is a property - where the first is the num of rows, and second is column
data.shape
# Out:
# (504, 25)

# %%
data.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381         0
# 1          2           Bearing Ball       BA-8327         0
# 2          3        BB Ball Bearing       BE-2349         1
# 3          4  Headset Ball Bearings       BE-2908         0
# 4        316                  Blade       BL-2036         1
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                  0   NaN              1000           750           0.0
# 1                  0   NaN              1000           750           0.0
# 2                  0   NaN               800           600           0.0
# 3                  0   NaN               800           600           0.0
# 4                  0   NaN               800           600           0.0
#
#    ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 0        0.0  ...         NaN   NaN   NaN                   NaN
# ...

# %%
data.tail(10)
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  \
# 494        990  Mountain-500 Black 42    BK-M18B-42         1
# 495        991  Mountain-500 Black 44    BK-M18B-44         1
# 496        992  Mountain-500 Black 48    BK-M18B-48         1
# 497        993  Mountain-500 Black 52    BK-M18B-52         1
# 498        994      LL Bottom Bracket       BB-7421         1
# 499        995      ML Bottom Bracket       BB-8107         1
# 500        996      HL Bottom Bracket       BB-9108         1
# 501        997      Road-750 Black 44    BK-R19B-44         1
# 502        998      Road-750 Black 48    BK-R19B-48         1
# 503        999      Road-750 Black 52    BK-R19B-52         1
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 494                  1  Black               100            75      294.5797
# 495                  1  Black               100            75      294.5797
# ...

# %%
# extract a specific column of data
# this gives us a series
safety = data['SafetyStockLevel']

# %%
type(safety)
# Out:
# pandas.core.series.Series

# %%
# there is a different between a series and a data frame
# get a series - use the column name in a single set of square brackets
safety = data[['SafetyStockLevel']]

# %%
type(safety)
# Out:
# pandas.core.frame.DataFrame

# %%
# use single square brackets to get a series
safety = data['SafetyStockLevel']
safety
# Out:
# 0      1000
# 1      1000
# 2       800
# 3       800
# 4       800
# 5       500
# 6       500
# 7       500
# 8      1000
# 9      1000
# 10     1000
# 11     1000
# 12     1000
# 13     1000
# 14     1000
# 15      800
# 16     1000
# 17     1000
# 18     1000
# 19      800
# 20      500
# 21     1000
# 22     1000
# 23     1000
# 24     1000
# 25     1000
# 26     1000
# 27     1000
# 28     1000
# 29     1000
#        ...
# 474     100
# 475     100
# 476     100
# 477     100
# 478     100
# 479     100
# 480     100
# 481     100
# 482     100
# 483     100
# 484     100
# 485     100
# 486     100
# 487     100
# 488     100
# 489     100
# 490     100
# 491     100
# 492     100
# 493     100
# 494     100
# 495     100
# 496     100
# 497     100
# 498     500
# 499     500
# 500     500
# 501     100
# 502     100
# 503     100
# Name: SafetyStockLevel, Length: 504, dtype: int64

# %%
# use double square brackets to get a data frame
safety2 = data[['SafetyStockLevel']]
safety2
# Out:
#      SafetyStockLevel
# 0                1000
# 1                1000
# 2                 800
# 3                 800
# 4                 800
# 5                 500
# 6                 500
# 7                 500
# 8                1000
# 9                1000
# 10               1000
# 11               1000
# 12               1000
# 13               1000
# 14               1000
# 15                800
# 16               1000
# 17               1000
# 18               1000
# 19                800
# 20                500
# 21               1000
# 22               1000
# 23               1000
# 24               1000
# 25               1000
# 26               1000
# 27               1000
# 28               1000
# 29               1000
# ..                ...
# 474               100
# 475               100
# 476               100
# 477               100
# 478               100
# 479               100
# 480               100
# 481               100
# 482               100
# ...

# %%
# return multiple columns
data[['ProductID','Color','ReorderPoint']]
# Out:
#      ProductID   Color  ReorderPoint
# 0            1     NaN           750
# 1            2     NaN           750
# 2            3     NaN           600
# 3            4     NaN           600
# 4          316     NaN           600
# 5          317   Black           375
# 6          318   Black           375
# 7          319   Black           375
# 8          320  Silver           750
# 9          321  Silver           750
# 10         322   Black           750
# 11         323     NaN           750
# 12         324     NaN           750
# 13         325     NaN           750
# 14         326     NaN           750
# 15         327     NaN           600
# 16         328     NaN           750
# 17         329     NaN           750
# 18         330     NaN           750
# 19         331     NaN           600
# 20         332  Silver           375
# 21         341     NaN           750
# 22         342     NaN           750
# 23         343     NaN           750
# ...

# %%
data[['ProductID','Color','ReorderPoint']].head(10)
# Out:
#    ProductID   Color  ReorderPoint
# 0          1     NaN           750
# 1          2     NaN           750
# 2          3     NaN           600
# 3          4     NaN           600
# 4        316     NaN           600
# 5        317   Black           375
# 6        318   Black           375
# 7        319   Black           375
# 8        320  Silver           750
# 9        321  Silver           750

# %%
data[['ProductID','Color','ReorderPoint']].head(10).shape
# Out:
# (10, 3)

# %%
# show all the products that are black
data[data['Color']=='Black']
# Out:
#      ProductID                          Name ProductNumber  MakeFlag  \
# 5          317                   LL Crankarm       CA-5965         0
# 6          318                   ML Crankarm       CA-6738         0
# 7          319                   HL Crankarm       CA-7457         0
# 10         322                     Chainring       CR-7833         0
# 209        680      HL Road Frame - Black 58    FR-R92B-58         1
# 212        708        Sport-100 Helmet Black       HL-U509         0
# 226        722      LL Road Frame - Black 58    FR-R38B-58         1
# 227        723      LL Road Frame - Black 60    FR-R38B-60         1
# 228        724      LL Road Frame - Black 62    FR-R38B-62         1
# 240        736      LL Road Frame - Black 44    FR-R38B-44         1
# 241        737      LL Road Frame - Black 48    FR-R38B-48         1
# 242        738      LL Road Frame - Black 52    FR-R38B-52         1
# 247        743  HL Mountain Frame - Black 42    FR-M94B-42         1
# ...

# %%
data[data['Color']=='Black'][['ProductID','ProductNumber']]
# Out:
#      ProductID ProductNumber
# 5          317       CA-5965
# 6          318       CA-6738
# 7          319       CA-7457
# 10         322       CR-7833
# 209        680    FR-R92B-58
# 212        708       HL-U509
# 226        722    FR-R38B-58
# 227        723    FR-R38B-60
# 228        724    FR-R38B-62
# 240        736    FR-R38B-44
# 241        737    FR-R38B-48
# 242        738    FR-R38B-52
# 247        743    FR-M94B-42
# 248        744    FR-M94B-44
# 249        745    FR-M94B-48
# 250        746    FR-M94B-46
# 251        747    FR-M94B-38
# 269        765    BK-R50B-58
# 270        766    BK-R50B-60
# 271        767    BK-R50B-62
# 272        768    BK-R50B-44
# 273        769    BK-R50B-48
# 274        770    BK-R50B-52
# 279        775    BK-M82B-38
# 280        776    BK-M82B-42
# 281        777    BK-M82B-44
# 282        778    BK-M82B-48
# 286        782    BK-M68B-38
# 287        783    BK-M68B-42
# 288        784    BK-M68B-46
# ..         ...           ...
# ...

# %%
# show product ID and name of all items with stock levels greater than 250
# this lets me check
data[data['SafetyStockLevel']>=250][['ProductID','Name','SafetyStockLevel']]
# Out:
#      ProductID                             Name  SafetyStockLevel
# 0            1                  Adjustable Race              1000
# 1            2                     Bearing Ball              1000
# 2            3                  BB Ball Bearing               800
# 3            4            Headset Ball Bearings               800
# 4          316                            Blade               800
# 5          317                      LL Crankarm               500
# 6          318                      ML Crankarm               500
# 7          319                      HL Crankarm               500
# 8          320                  Chainring Bolts              1000
# 9          321                    Chainring Nut              1000
# 10         322                        Chainring              1000
# 11         323                       Crown Race              1000
# 12         324                      Chain Stays              1000
# ...

# %%
# this is what was requested
data[data['SafetyStockLevel']>=250][['ProductID','Name']]
# Out:
#      ProductID                             Name
# 0            1                  Adjustable Race
# 1            2                     Bearing Ball
# 2            3                  BB Ball Bearing
# 3            4            Headset Ball Bearings
# 4          316                            Blade
# 5          317                      LL Crankarm
# 6          318                      ML Crankarm
# 7          319                      HL Crankarm
# 8          320                  Chainring Bolts
# 9          321                    Chainring Nut
# 10         322                        Chainring
# 11         323                       Crown Race
# 12         324                      Chain Stays
# 13         325                          Decal 1
# 14         326                          Decal 2
# 15         327                        Down Tube
# 16         328                Mountain End Caps
# 17         329                    Road End Caps
# 18         330                 Touring End Caps
# ...

# %%
# count values
data['Color'].value_counts()
# Out:
# Black           93
# Silver          43
# Red             38
# Yellow          36
# Blue            26
# Multi            8
# Silver/Black     7
# White            4
# Grey             1
# Name: Color, dtype: int64

# %%
# how many colors are there?
# drops anything that is NaN or null 
data['Color'].nunique()
# Out:
# 9

# %%
# sorting -- ascending by default
data.sort_values(by='ListPrice',ascending=False).head(10)
# Out:
#      ProductID                    Name ProductNumber  MakeFlag  \
# 256        752         Road-150 Red 52    BK-R93R-52         1
# 254        750         Road-150 Red 44    BK-R93R-44         1
# 257        753         Road-150 Red 56    BK-R93R-56         1
# 255        751         Road-150 Red 48    BK-R93R-48         1
# 253        749         Road-150 Red 62    BK-R93R-62         1
# 276        772  Mountain-100 Silver 42    BK-M82S-42         1
# 275        771  Mountain-100 Silver 38    BK-M82S-38         1
# 278        774  Mountain-100 Silver 48    BK-M82S-48         1
# 277        773  Mountain-100 Silver 44    BK-M82S-44         1
# 282        778   Mountain-100 Black 48    BK-M82B-48         1
#
#      FinishedGoodsFlag   Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 256                  1     Red               100            75     2171.2942
# 254                  1     Red               100            75     2171.2942
# ...
